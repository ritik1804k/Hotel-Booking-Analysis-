# %% [markdown]
# <a href="https://colab.research.google.com/github/ritik1804k/My-awesome-repo/blob/main/EDA_ON_FIFA_World_Cup_2022_Players_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b>The FIFA World Cup is a professional football tournament held between national football teams, Organised by FIFA. The tournament, held every four years, was first played in 1930 in Uruguay, and has been contested by 32 teams since the 1998 event. The tournament was contested with eight round-robin groups followed by a knockout round for 16 teams.
#
# ## <b>This tournament was the last with 32 participating teams, with the number of teams being increased to 48 for the 2026 edition. To avoid the extremes of Qatar's hot climate, the event was held during November and December. It was held over a reduced time frame of 29 days with 64 matches played in eight venues across five cities. Qatar entered the event—their first World Cup—automatically as the host's national team, alongside 31 teams determined by the qualification process.</b>

# %%
# giving some playerd their jersey names
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# uploading the csv file to the Qatar FIFA stadium 
path  = '/content/drive/MyDrive/Colab Notebooks/access the data/FIFA dataset/FIFA WC 2022 Players Stats.csv'
FIFA_df = pd.read_csv(path)

# %%
# viewing column and the data inside them and how they correlate
FIFA_df.head(10)
# Out:
#   Nationality   FIFA Ranking  National Team Kit Sponsor Position  \
# 0    Argentina              2                    Adidas       GK
# 1    Argentina              2                    Adidas       GK
# 2    Argentina              2                    Adidas       GK
# 3    Argentina              2                    Adidas       DF
# 4    Argentina              2                    Adidas       DF
# 5    Argentina              2                    Adidas       DF
# 6    Argentina              2                    Adidas       DF
# 7    Argentina              2                    Adidas       DF
# 8    Argentina              2                    Adidas       DF
# 9    Argentina              2                    Adidas       DF
#
#    National Team Jersey Number    Player DOB            Club   \
# 0                         23.0   Sep 2, 1992      Aston Villa
# 1                          1.0  Oct 16, 1986            River
# ...

# %%
#  bottom ten rows of dataframe
FIFA_df.tail(10)
# Out:
#     Nationality   FIFA Ranking  National Team Kit Sponsor Position  \
# 804       Canada             53                      Nike       MF
# 805       Canada             53                      Nike       MF
# 806       Canada             53                      Nike       FW
# 807       Canada             53                      Nike       FW
# 808       Canada             53                      Nike       FW
# 809       Canada             53                      Nike       FW
# 810       Canada             53                      Nike       FW
# 811       Canada             53                      Nike       FW
# 812       Canada             53                      Nike       FW
# 813       Canada             53                      Nike       FW
#
#      National Team Jersey Number    Player DOB                Club   \
# 804                          8.0  Feb 13, 1998          KMSK Deinze
# 805                         15.0   Jun 6, 2002              Watford
# ...

# %%
# checking for columns those are empty
FIFA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 814 entries, 0 to 813
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Nationality                  814 non-null    object
#  1   FIFA Ranking                 814 non-null    int64
#  2   National Team Kit Sponsor    813 non-null    object
#  3   Position                     814 non-null    object
#  4   National Team Jersey Number  813 non-null    float64
#  5   Player DOB                   814 non-null    object
#  6   Club                         814 non-null    object
#  7   Player Name                  814 non-null    object
#  8    Appearances                 814 non-null    object
#  9   Goals Scored                 813 non-null    object
#  10  Assists Provided             813 non-null    object
#  11  Dribbles per 90              813 non-null    object
#  12  Interceptions per 90         813 non-null    object
# ...

# %%
# computing and displaying summary statistics for our 2022 FIFA WORLD CUP analysis
FIFA_df.describe()
# Out:
#        FIFA Ranking   National Team Jersey Number
# count     814.000000                   813.000000
# mean       21.713759                    13.507995
# std        16.159655                     7.523788
# min         1.000000                     1.000000
# 25%         9.000000                     7.000000
# 50%        18.000000                    14.000000
# 75%        29.000000                    20.000000
# max        60.000000                    26.000000

# %%
FIFA_df.columns
# Out:
# Index(['Nationality ', 'FIFA Ranking ', 'National Team Kit Sponsor',
#        'Position', 'National Team Jersey Number', 'Player DOB', 'Club ',
#        'Player Name ', ' Appearances', 'Goals Scored ', 'Assists Provided ',
#        'Dribbles per 90', 'Interceptions per 90', 'Tackles per 90',
#        'Total Duels Won per 90', 'Save Percentage', 'Clean Sheets',
#        'Brand Sponsor/Brand Used'],
#       dtype='object')

# %% [markdown]
# # Columns Discription
#
# * Nationality : Player representing that particular nation.
# * FIFA Ranking : The teams of the men's member nations of FIFA, football's
# world governing body, are ranked based on their game results with the most successful teams being ranked highest.
# *  National Team Kit Sponsor : A particular brand sponsoring that football team and preparing jersey for them.
# * Position : The specific role that a player takes on the field is referred to as their "position".
# * National Team Jersey Number : Marking of a number behind each player's jersey.
# * Player DOB : Player Date of Birth.
# * Club : Club are sometimes used interchangeably by supporters, typically referring to the team within the club playing in the highest division or competition.
# * Player Name : Name used in Fifa.
# * Appearances : A set number of games that the player must appear on the ground for the club.
# * Goals Scored : A goal is scored when the whole of the ball passes over the goal line, between the goalposts and under the crossbar, provided that no offence has been committed by the player.
# * Assists Provided : Assists are awarded to a player who makes the final pass or cross before a goal is scored.
# * Dribbles per 90 : Dribble per 90 means travelling with the ball in between 90 minutes.
# * Interceptions per 90 : Number of times stealing the ball from your opposition in between 90 minutes.
# * Tackles per 90 : To seize and throw down or stop (an opposing player with the ball) in football.
# * Total Duels Won per 90 : The defensive player stopped the progression of the attacking player with the ball and didn't commit a foul, the defensive duel is considered won in those 90 minutes (and the linked offensive duel is considered lost).
# * Save Percentage : It is given as by dividing the number of saves by the total number of shots on goal.
# * Clean Sheets :  A goalkeeper is said to "keep a clean sheet" if they prevent their opponents scoring any goals during an entire match.
# * Brand Sponsor/Brand Used : Brand sponsorship is when a brand acts as a sponsor. The brand would choose the cause to support, be it an event, a small business, or a charity.

# %%
FIFA_df.shape
# Out:
# (814, 18)

# %%
# we should now clean and manipulate the dataset 
#looking for some null values
FIFA_df.isna().sum().sort_values(ascending = False)
# Out:
# Save Percentage                2
# Goals Scored                   1
# Assists Provided               1
# Total Duels Won per 90         1
# Tackles per 90                 1
# Interceptions per 90           1
# Dribbles per 90                1
# Brand Sponsor/Brand Used       1
# National Team Jersey Number    1
# National Team Kit Sponsor      1
#  Appearances                   0
# FIFA Ranking                   0
# Player Name                    0
# Club                           0
# Player DOB                     0
# Position                       0
# Clean Sheets                   0
# Nationality                    0
# dtype: int64

# %%
# Replacing all null values with 0
FIFA_df.fillna(0, inplace=True)

# %%
# Replace all occurrences of '-' with 0
FIFA_df.replace('-', 0, inplace=True)

# %%
FIFA_df
# Out:
#     Nationality   FIFA Ranking  National Team Kit Sponsor Position  \
# 0      Argentina              2                    Adidas       GK
# 1      Argentina              2                    Adidas       GK
# 2      Argentina              2                    Adidas       GK
# 3      Argentina              2                    Adidas       DF
# 4      Argentina              2                    Adidas       DF
# ..           ...            ...                       ...      ...
# 809       Canada             53                      Nike       FW
# 810       Canada             53                      Nike       FW
# 811       Canada             53                      Nike       FW
# 812       Canada             53                      Nike       FW
# 813       Canada             53                      Nike       FW
#
#      National Team Jersey Number    Player DOB          Club   \
# 0                           23.0   Sep 2, 1992    Aston Villa
# ...

# %%
# done with missing values in our party
FIFA_df.isna().sum().sort_values(ascending = False)
# Out:
# Nationality                    0
# FIFA Ranking                   0
# Clean Sheets                   0
# Save Percentage                0
# Total Duels Won per 90         0
# Tackles per 90                 0
# Interceptions per 90           0
# Dribbles per 90                0
# Assists Provided               0
# Goals Scored                   0
#  Appearances                   0
# Player Name                    0
# Club                           0
# Player DOB                     0
# National Team Jersey Number    0
# Position                       0
# National Team Kit Sponsor      0
# Brand Sponsor/Brand Used       0
# dtype: int64

# %%
#checking for duplicate rows
duplicate_rows =  FIFA_df.duplicated().value_counts()
print(f'All the True value are for duplicate rows: {duplicate_rows}')
# Out:
# All the True value are for duplicate rows: False    814
# dtype: int64

# %% [markdown]
# #***Exploratory Data Analysis***

# %% [markdown]
# #What is the distribution of National Team Kit Sponsor in the dataset?

# %%
# Get the count of players for each nationality
nationality_counts = FIFA_df['National Team Kit Sponsor'].value_counts()
nationality_counts
# Out:
# Nike              331
# Adidas            178
# Puma              151
# Marathon           26
# Hummel             26
# Kappa              26
# Majid              25
# New Balance        25
# One All Sports     24
# Nke                 1
# 0                   1
# Name: National Team Kit Sponsor, dtype: int64

# %%
# Plot the distribution of National Team Kit Sponsor
plt.rcParams['figure.figsize'] = (12,6)
sns.barplot(x=nationality_counts.index, y=nationality_counts.values)
plt.xticks(rotation=90)
plt.xlabel("BRAND NAMES")
plt.ylabel("Number of Players")
plt.title("Distribution of Player Branding")
plt.show()

# %%
#Replace spaces with underscores in the column names
FIFA_df.columns = [col.replace(" ", "_") for col in FIFA_df.columns]

# %%
FIFA_df.head()
# Out:
#   Nationality_  FIFA_Ranking_ National_Team_Kit_Sponsor Position  \
# 0    Argentina              2                    Adidas       GK
# 1    Argentina              2                    Adidas       GK
# 2    Argentina              2                    Adidas       GK
# 3    Argentina              2                    Adidas       DF
# 4    Argentina              2                    Adidas       DF
#
#    National_Team_Jersey_Number    Player_DOB        Club_       Player_Name_  \
# 0                         23.0   Sep 2, 1992  Aston Villa  Emiliano Martinez
# 1                          1.0  Oct 16, 1986        River      Franco Armani
# 2                         12.0  May 20, 1992   Villarreal     Geronimo Rulli
# 3                         19.0  Feb 12, 1988      Benfica   Nicolas Otamendi
# 4                          8.0  Oct 28, 1991      Sevilla       Marcos Acuna
#
#   _Appearances Goals_Scored_ Assists_Provided_ Dribbles_per_90  \
# ...

# %% [markdown]
# #Which countries have the most number of players participating in the World Cup?

# %%
# countries have the most number of players participating 
grouped = FIFA_df.groupby('Nationality_')
plt.rcParams['figure.figsize'] = (12,10)
counts = grouped.size().sort_values(ascending=False)
plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
plt.title('Number of Players from Each Country')
plt.show()

# %% [markdown]
# # What is the position-wise distribution of players in each team?

# %%
# position-wise distribution of players in each team
grouped = FIFA_df.groupby(['Nationality_', 'Position'])
counts = grouped.size().unstack(fill_value=0)
counts.plot(kind='bar', stacked=True)
plt.xlabel('Team')
plt.ylabel('Number of Players')
plt.title('Position-wise Distribution of Players in Each Team')
plt.show()

# %%
from datetime import datetime, date

# %%
# creating a new column
# convert the DOB column to datetime objects
FIFA_df['Player_DOB'] = FIFA_df['Player_DOB'].apply(lambda x: datetime.strptime(x,  '%B %d, %Y'))

# calculate the age for each date of birth
today = date.today()
FIFA_df['Age'] = (today - FIFA_df['Player_DOB']).apply(lambda x: x.days) // 365.25

# %% [markdown]
#  # How is the number of goals scored by players related to their age?

# %%
# Q13: How is the number of goals scored by players related to their age?
plt.scatter(df['age'], df['goals_scored'])
plt.xlabel('Age')
plt.ylabel('Goals Scored')
plt.title('Relationship between Age and Goals Scored by Players')
plt.show()
